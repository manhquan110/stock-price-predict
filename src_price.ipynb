# %%
import pandas as pd
from pandas import read_csv, datetime
from matplotlib import pyplot
import numpy as np

# %%
# read data
raw_data = read_csv('dataset/UAL_share.csv')

tweet_sentiment = pd.read_csv('dataset/sentiment_twitter.csv')
data = raw_data.drop(['date'], axis=1)
# [len(Y_base)-len(tweet):,:]
data.drop(data.index[[range(0,len(data.index)-len(tweet_sentiment.index))]], inplace=True)
data.info()
data.head()
# tweet_sentiment.info()
# tweet_sentiment.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1862 entries, 984 to 2845
# Data columns (total 5 columns):
# open      1862 non-null float64
# high      1862 non-null float64
# low       1862 non-null float64
# close     1862 non-null float64
# volume    1862 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 87.3 KB
#       open   high    low  close    volume
# 984  12.99  13.11  12.53  12.80   8785900
# 985  12.87  14.10  12.87  13.91  23646300
# 986  13.74  13.99  13.13  13.27  15398700
# 987  13.20  13.95  13.20  13.55  10177000
# 988  13.56  13.86  13.13  13.33   5896400

# %%
#t-1 become input of t by shifting the volume
price_2_predict = data['close']
price_2_predict = price_2_predict.shift(periods=-1)
data['nextday_price'] = price_2_predict
data.rename(columns={'close': 'today_price'}, inplace=True)
#drop the last row because the NAN of shifting operator
data.drop(data.index[len(data)-1], inplace=True)
data.head()
# Out:
#       open   high    low  today_price    volume  nextday_price
# 984  12.99  13.11  12.53        12.80   8785900          13.91
# 985  12.87  14.10  12.87        13.91  23646300          13.27
# 986  13.74  13.99  13.13        13.27  15398700          13.55
# 987  13.20  13.95  13.20        13.55  10177000          13.33
# 988  13.56  13.86  13.13        13.33   5896400          13.11

# %%
data_info = {}
#normalize data
mean_data = np.mean(data, axis=0) 
std_data = np.std(data, axis=0)
data_info['mean_data'] = mean_data
data_info['std_data'] = std_data
print mean_data
print std_data
data = data.apply(lambda x: (x-np.mean(x))/np.std(x))
data.info()
data.head()
# Out:
# open             3.853887e+01
# high             3.919567e+01
# low              3.790066e+01
# today_price      3.854502e+01
# volume           5.908570e+06
# nextday_price    3.858181e+01
# dtype: float64
# open             1.773604e+01
# high             1.793613e+01
# low              1.753158e+01
# today_price      1.774230e+01
# volume           3.557585e+06
# nextday_price    1.775983e+01
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1861 entries, 984 to 2844
# Data columns (total 6 columns):
# open             1861 non-null float64
# high             1861 non-null float64
# low              1861 non-null float64
# today_price      1861 non-null float64
# volume           1861 non-null float64
# nextday_price    1861 non-null float64
# dtypes: float64(6)
# memory usage: 101.8 KB
#          open      high       low  today_price    volume  nextday_price
# 984 -1.440506 -1.454364 -1.447141    -1.451053  0.808787      -1.389191
# 985 -1.447272 -1.399168 -1.427747    -1.388491  4.985890      -1.425228
# 986 -1.398219 -1.405301 -1.412917    -1.424563  2.667576      -1.409462
# 987 -1.428665 -1.407531 -1.408924    -1.408782  1.199811      -1.421849
# 988 -1.408368 -1.412549 -1.412917    -1.421181 -0.003421      -1.434237

# %%
data['nextday_price'].plot(figsize=(30, 10))
pyplot.show()

# %%
data_np = np.hsplit(data.as_matrix(), [0,-1])
X = data_np[1]
Y = data_np[-1]
max_Y = np.max(Y)
data_info['max_Y'] = max_Y
#scale Y to [-1;1]
Y /= max_Y
Y_base = np.array(Y)
# split into train and test sets
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size
train_X, test_X = X[0:train_size,:], X[train_size:len(X),:]
train_Y, test_Y = Y[0:train_size,:], Y[train_size:len(Y),:]
# reshape input to be [samples, time steps, features]
train_X = np.reshape(train_X, (train_X.shape[0], 1, train_X.shape[1]))
test_X = np.reshape(test_X, (test_X.shape[0], 1, test_X.shape[1]))
print "X train shape: ", train_X.shape
print "Y train shape: ", train_Y.shape
print "X test shape: ", test_X.shape
print "Y test shape: ", test_Y.shape
# Out:
# X train shape:  (1488, 1, 5)
# Y train shape:  (1488, 1)
# X test shape:  (373, 1, 5)
# Y test shape:  (373, 1)

# %%
#model setting
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.models import model_from_json
from keras.layers.core import Dropout

batch_size = 1
pretrain = False

if not pretrain:
    model = Sequential()
    model.add(LSTM(4, batch_input_shape=(batch_size, train_X.shape[1], train_X.shape[2]), stateful=True, return_sequences=True))
    model.add(LSTM(4, batch_input_shape=(batch_size, 1, 1), stateful=True))
    model.add(Dense(1, activation='tanh'))
else:
    json_model = open('model.json')
    model = json_model.read()
    json_model.close()
    model = model_from_json(model)
    model.load_weights('model_weights.h5')
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse'])

# %%
if not pretrain:

    #training
    model.fit(train_X, train_Y, epochs=100, batch_size=1, verbose=2)
    import h5py
    # save the model +
    info = model.to_json()
    with open("./model.json", "w") as json_file:
        json_file.write(info)
    model.save_weights("./model_weights.h5")
# Out:
# Epoch 1/100
# 26s - loss: 0.0857 - mean_squared_error: 0.0857
# Epoch 2/100
# 21s - loss: 0.0144 - mean_squared_error: 0.0144
# Epoch 3/100
# 21s - loss: 0.0065 - mean_squared_error: 0.0065
# Epoch 4/100
# 21s - loss: 0.0034 - mean_squared_error: 0.0034
# Epoch 5/100
# 21s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 6/100
# 21s - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 7/100
# 21s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 8/100
# 21s - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 9/100
# 20s - loss: 9.5170e-04 - mean_squared_error: 9.5170e-04
# Epoch 10/100
# 19s - loss: 8.7223e-04 - mean_squared_error: 8.7223e-04
# Epoch 11/100
# 23s - loss: 8.3662e-04 - mean_squared_error: 8.3662e-04
# Epoch 12/100
# 23s - loss: 7.7013e-04 - mean_squared_error: 7.7013e-04
# Epoch 13/100
# 23s - loss: 7.8083e-04 - mean_squared_error: 7.8083e-04
# Epoch 14/100
# 23s - loss: 7.2254e-04 - mean_squared_error: 7.2254e-04
# Epoch 15/100
# 23s - loss: 7.0587e-04 - mean_squared_error: 7.0587e-04
# Epoch 16/100
# 23s - loss: 7.2384e-04 - mean_squared_error: 7.2384e-04
# Epoch 17/100
# 23s - loss: 6.7768e-04 - mean_squared_error: 6.7768e-04
# Epoch 18/100
# 23s - loss: 6.6693e-04 - mean_squared_error: 6.6693e-04
# Epoch 19/100
# 23s - loss: 6.6699e-04 - mean_squared_error: 6.6699e-04
# Epoch 20/100
# 23s - loss: 6.4050e-04 - mean_squared_error: 6.4050e-04
# Epoch 21/100
# 22s - loss: 6.6222e-04 - mean_squared_error: 6.6222e-04
# Epoch 22/100
# 23s - loss: 6.3342e-04 - mean_squared_error: 6.3342e-04
# Epoch 23/100
# 26s - loss: 6.3497e-04 - mean_squared_error: 6.3497e-04
# Epoch 24/100
# 23s - loss: 6.2952e-04 - mean_squared_error: 6.2952e-04
# Epoch 25/100
# 22s - loss: 6.3264e-04 - mean_squared_error: 6.3264e-04
# Epoch 26/100
# 23s - loss: 6.5089e-04 - mean_squared_error: 6.5089e-04
# Epoch 27/100
# 24s - loss: 6.2178e-04 - mean_squared_error: 6.2178e-04
# Epoch 28/100
# 22s - loss: 6.0896e-04 - mean_squared_error: 6.0896e-04
# Epoch 29/100
# 22s - loss: 6.1579e-04 - mean_squared_error: 6.1579e-04
# Epoch 30/100
# 22s - loss: 6.0734e-04 - mean_squared_error: 6.0734e-04
# Epoch 31/100
# 22s - loss: 5.9225e-04 - mean_squared_error: 5.9225e-04
# Epoch 32/100
# 22s - loss: 6.0257e-04 - mean_squared_error: 6.0257e-04
# Epoch 33/100
# 22s - loss: 6.1017e-04 - mean_squared_error: 6.1017e-04
# Epoch 34/100
# 22s - loss: 5.9636e-04 - mean_squared_error: 5.9636e-04
# Epoch 35/100
# 22s - loss: 6.2172e-04 - mean_squared_error: 6.2172e-04
# Epoch 36/100
# 22s - loss: 5.7753e-04 - mean_squared_error: 5.7753e-04
# Epoch 37/100
# 23s - loss: 5.9185e-04 - mean_squared_error: 5.9185e-04
# Epoch 38/100
# 23s - loss: 5.8740e-04 - mean_squared_error: 5.8740e-04
# Epoch 39/100
# 23s - loss: 5.9768e-04 - mean_squared_error: 5.9768e-04
# Epoch 40/100
# 23s - loss: 5.8218e-04 - mean_squared_error: 5.8218e-04
# Epoch 41/100
# 23s - loss: 5.7516e-04 - mean_squared_error: 5.7516e-04
# Epoch 42/100
# 23s - loss: 5.8580e-04 - mean_squared_error: 5.8580e-04
# Epoch 43/100
# 22s - loss: 5.9114e-04 - mean_squared_error: 5.9114e-04
# Epoch 44/100
# 22s - loss: 5.7185e-04 - mean_squared_error: 5.7185e-04
# Epoch 45/100
# 23s - loss: 5.8027e-04 - mean_squared_error: 5.8027e-04
# Epoch 46/100
# 23s - loss: 5.8554e-04 - mean_squared_error: 5.8554e-04
# Epoch 47/100
# 22s - loss: 5.8988e-04 - mean_squared_error: 5.8988e-04
# Epoch 48/100
# 22s - loss: 5.5522e-04 - mean_squared_error: 5.5522e-04
# Epoch 49/100
# 22s - loss: 5.6080e-04 - mean_squared_error: 5.6080e-04
# Epoch 50/100
# 22s - loss: 5.6502e-04 - mean_squared_error: 5.6502e-04
# Epoch 51/100
# 22s - loss: 5.6496e-04 - mean_squared_error: 5.6496e-04
# Epoch 52/100
# 22s - loss: 5.7975e-04 - mean_squared_error: 5.7975e-04
# Epoch 53/100
# 22s - loss: 5.7655e-04 - mean_squared_error: 5.7655e-04
# Epoch 54/100
# 22s - loss: 5.7848e-04 - mean_squared_error: 5.7848e-04
# Epoch 55/100
# 22s - loss: 5.6575e-04 - mean_squared_error: 5.6575e-04
# Epoch 56/100
# 21s - loss: 5.6192e-04 - mean_squared_error: 5.6192e-04
# Epoch 57/100
# 21s - loss: 5.6692e-04 - mean_squared_error: 5.6692e-04
# Epoch 58/100
# 21s - loss: 5.5851e-04 - mean_squared_error: 5.5851e-04
# Epoch 59/100
# 22s - loss: 5.6574e-04 - mean_squared_error: 5.6574e-04
# Epoch 60/100
# 23s - loss: 5.6081e-04 - mean_squared_error: 5.6081e-04
# Epoch 61/100
# 22s - loss: 5.6568e-04 - mean_squared_error: 5.6568e-04
# Epoch 62/100
# 21s - loss: 5.7348e-04 - mean_squared_error: 5.7348e-04
# Epoch 63/100
# 21s - loss: 5.7249e-04 - mean_squared_error: 5.7249e-04
# Epoch 64/100
# 22s - loss: 5.6674e-04 - mean_squared_error: 5.6674e-04
# Epoch 65/100
# 23s - loss: 5.6107e-04 - mean_squared_error: 5.6107e-04
# Epoch 66/100
# 22s - loss: 5.7170e-04 - mean_squared_error: 5.7170e-04
# Epoch 67/100
# 21s - loss: 5.6534e-04 - mean_squared_error: 5.6534e-04
# Epoch 68/100
# 21s - loss: 5.5935e-04 - mean_squared_error: 5.5935e-04
# Epoch 69/100
# 21s - loss: 5.5275e-04 - mean_squared_error: 5.5275e-04
# Epoch 70/100
# 22s - loss: 5.6593e-04 - mean_squared_error: 5.6593e-04
# Epoch 71/100
# 21s - loss: 5.6219e-04 - mean_squared_error: 5.6219e-04
# Epoch 72/100
# 21s - loss: 5.7465e-04 - mean_squared_error: 5.7465e-04
# Epoch 73/100
# 21s - loss: 5.6635e-04 - mean_squared_error: 5.6635e-04
# Epoch 74/100
# 21s - loss: 5.5727e-04 - mean_squared_error: 5.5727e-04
# Epoch 75/100
# 22s - loss: 5.6029e-04 - mean_squared_error: 5.6029e-04
# Epoch 76/100
# 21s - loss: 5.6095e-04 - mean_squared_error: 5.6095e-04
# Epoch 77/100
# 21s - loss: 5.5926e-04 - mean_squared_error: 5.5926e-04
# Epoch 78/100
# 21s - loss: 5.7411e-04 - mean_squared_error: 5.7411e-04
# Epoch 79/100
# 22s - loss: 5.5806e-04 - mean_squared_error: 5.5806e-04
# Epoch 80/100
# 22s - loss: 5.6560e-04 - mean_squared_error: 5.6560e-04
# Epoch 81/100
# 22s - loss: 5.4658e-04 - mean_squared_error: 5.4658e-04
# Epoch 82/100
# 21s - loss: 5.6109e-04 - mean_squared_error: 5.6109e-04
# Epoch 83/100
# 21s - loss: 5.5060e-04 - mean_squared_error: 5.5060e-04
# Epoch 84/100
# 21s - loss: 5.5745e-04 - mean_squared_error: 5.5745e-04
# Epoch 85/100
# 21s - loss: 5.6362e-04 - mean_squared_error: 5.6362e-04
# Epoch 86/100
# 21s - loss: 5.7269e-04 - mean_squared_error: 5.7269e-04
# Epoch 87/100
# 21s - loss: 5.5329e-04 - mean_squared_error: 5.5329e-04
# Epoch 88/100
# 21s - loss: 5.5828e-04 - mean_squared_error: 5.5828e-04
# Epoch 89/100
# 21s - loss: 5.5341e-04 - mean_squared_error: 5.5341e-04
# Epoch 90/100
# 21s - loss: 5.5851e-04 - mean_squared_error: 5.5851e-04
# Epoch 91/100
# 21s - loss: 5.4073e-04 - mean_squared_error: 5.4073e-04
# Epoch 92/100
# 21s - loss: 5.4655e-04 - mean_squared_error: 5.4655e-04
# Epoch 93/100
# 21s - loss: 5.5691e-04 - mean_squared_error: 5.5691e-04
# Epoch 94/100
# 21s - loss: 5.7231e-04 - mean_squared_error: 5.7231e-04
# Epoch 95/100
# 21s - loss: 5.4927e-04 - mean_squared_error: 5.4927e-04
# Epoch 96/100
# 21s - loss: 5.5170e-04 - mean_squared_error: 5.5170e-04
# Epoch 97/100
# 21s - loss: 5.5007e-04 - mean_squared_error: 5.5007e-04
# Epoch 98/100
# 22s - loss: 5.6407e-04 - mean_squared_error: 5.6407e-04
# Epoch 99/100
# 21s - loss: 5.5518e-04 - mean_squared_error: 5.5518e-04
# Epoch 100/100
# 16s - loss: 5.5110e-04 - mean_squared_error: 5.5110e-04

# %%
import math
from sklearn.metrics import mean_squared_error
plt = pyplot
plt.rcParams["figure.figsize"] = (30,50)

def invertScale(data, data_info):
    std_data = data_info['std_data']['nextday_price']
    mean_data = data_info['mean_data']['nextday_price']
    max_scale = data_info['max_Y']
    return data*max_scale*std_data + mean_data
def visual_result(model, train_X, train_Y, test_X, test_Y, Y_base, data_info):
    # make predictions
    trainPredict = model.predict(train_X, batch_size=1)
    testPredict = model.predict(test_X, batch_size=1)
    # invert predictions
    trainPredict = invertScale(trainPredict, data_info)
    trainY = invertScale(train_Y, data_info)
    testPredict = invertScale(testPredict, data_info)
    testY = invertScale(test_Y, data_info)
    
    # calculate root mean squared error
    trainScore = math.sqrt(mean_squared_error(trainY, trainPredict))
    print('Train Score: %.2f RMSE' % (trainScore))
    testScore = math.sqrt(mean_squared_error(testY, testPredict))
    print('Test Score: %.2f RMSE' % (testScore))
    trainPredictPlot = np.empty(shape=(len(Y_base)))
    trainPredictPlot[:] = np.nan
    trainPredictPlot[0:len(trainPredict)] = trainPredict[:,0]
    # shift test predictions for plotting
    testPredictPlot = np.empty(shape=(len(Y_base)))
    testPredictPlot[:] = np.nan
    testPredictPlot[len(trainPredict):] = testPredict[:,0]
    #baseline 
    baseline = invertScale(Y_base, data_info)

    return baseline, trainPredictPlot, testPredictPlot

# %%
baseline, trainPredictPlot, testPredictPlot = visual_result(model, train_X, train_Y, test_X, test_Y, Y_base, data_info)
plt.plot(baseline)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Train Score: 0.41 RMSE
# Test Score: 1.14 RMSE

# %%
#-------------------------------------------------------------------------------------------------------------------------
"""
stock model with twitter
the sentiment of twitter already norm by std and mean
we collect tweet day by day from twitter, and using textblob framework to compute sentiment and the output is
    a score is a pair of (subject, polarity) after that we take polarity - subject. To compute sentiment of a day
    we take average sum of all the sentiment is already computed.
"""
# add std and mean of sentiment to data info 
data_info['std_data']['twitter_sentiment_std'] = 0.106175849012
data_info['mean_data']['twitter_sentiment_mean'] = -0.302494532549
# tweet_sentiment = pd.read_csv('sentiment_twitter.csv')
# drop the last row
tweet_sentiment.drop(tweet_sentiment.index[len(tweet_sentiment)-1], inplace=True)
sentiment = tweet_sentiment['sentiment'].as_matrix()
retweet = tweet_sentiment['retweet'].as_matrix() + 1

tweet = sentiment*retweet
tweet_Y_base = Y_base[len(Y_base)-len(tweet):,:]
# create data with sentiment 
X_tweet = np.hstack((X[len(X)-len(tweet):,:], tweet.reshape((len(tweet),1))))
Y_tweet = Y[len(Y)-len(tweet):,:]
size = int(len(X_tweet) * 0.8)
tweet_train_X, tweet_test_X = X_tweet[0:size,:], X_tweet[size:len(X_tweet),:]
tweet_train_Y, tweet_test_Y = Y_tweet[0:size,:], Y_tweet[size:len(X_tweet),:]

tweet_train_X = np.reshape(tweet_train_X, (tweet_train_X.shape[0], 1, tweet_train_X.shape[1]))
tweet_test_X = np.reshape(tweet_test_X, (tweet_test_X.shape[0], 1, tweet_test_X.shape[1]))

print "tweet_X train shape: ", tweet_train_X.shape
print "tweet_Y train shape: ", tweet_train_Y.shape
print "tweet_X test shape: ", tweet_test_X.shape
print "tweet_Y test shape: ", tweet_test_Y.shape
# Out:
# tweet_X train shape:  (1487, 1, 6)
# tweet_Y train shape:  (1487, 1)
# tweet_X test shape:  (372, 1, 6)
# tweet_Y test shape:  (372, 1)

# %%
#define model
tweet_pretrain = False

if not tweet_pretrain:
    tweet_model = Sequential()
    tweet_model.add(LSTM(4, batch_input_shape=(batch_size, tweet_train_X.shape[1], tweet_train_X.shape[2]), stateful=True, return_sequences=True))
    tweet_model.add(LSTM(4, batch_input_shape=(batch_size, 1, 1), stateful=True))
    tweet_model.add(Dense(1, activation='tanh'))
else:
    json_model = open('tweet_model.json')
    tweet_model = json_model.read()
    json_model.close()
    tweet_model = model_from_json(model)
    tweet_model.load_weights('tweet_model_weights.h5')
tweet_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse'])

# %%
if not tweet_pretrain:

    #training
    tweet_model.fit(tweet_train_X, tweet_train_Y, epochs=100, batch_size=1, verbose=2)
    import h5py
    # save the tweet_model +
    info = tweet_model.to_json()
    with open("./tweet_model.json", "w") as json_file:
        json_file.write(info)
    tweet_model.save_weights("./tweet_model_weights.h5")
# Out:
# Epoch 1/100
# 23s - loss: 0.1007 - mean_squared_error: 0.1007
# Epoch 2/100
# 20s - loss: 0.0312 - mean_squared_error: 0.0312
# Epoch 3/100
# 21s - loss: 0.0139 - mean_squared_error: 0.0139
# Epoch 4/100
# 21s - loss: 0.0086 - mean_squared_error: 0.0086
# Epoch 5/100
# 21s - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 6/100
# 21s - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 7/100
# 23s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 8/100
# 22s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 9/100
# 21s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 10/100
# 21s - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 11/100
# 21s - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 12/100
# 21s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 13/100
# 21s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 14/100
# 22s - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 15/100
# 21s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 16/100
# 21s - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 17/100
# 21s - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 18/100
# 21s - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 19/100
# 22s - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 20/100
# 22s - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 21/100
# 22s - loss: 9.2481e-04 - mean_squared_error: 9.2481e-04
# Epoch 22/100
# 22s - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 23/100
# 21s - loss: 8.6622e-04 - mean_squared_error: 8.6622e-04
# Epoch 24/100
# 21s - loss: 8.5626e-04 - mean_squared_error: 8.5626e-04
# Epoch 25/100
# 21s - loss: 8.8614e-04 - mean_squared_error: 8.8614e-04
# Epoch 26/100
# 21s - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 27/100
# 21s - loss: 9.7209e-04 - mean_squared_error: 9.7209e-04
# Epoch 28/100
# 22s - loss: 8.4874e-04 - mean_squared_error: 8.4874e-04
# Epoch 29/100
# 21s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 30/100
# 21s - loss: 9.0589e-04 - mean_squared_error: 9.0589e-04
# Epoch 31/100
# 21s - loss: 7.4472e-04 - mean_squared_error: 7.4472e-04
# Epoch 32/100
# 21s - loss: 7.6546e-04 - mean_squared_error: 7.6546e-04
# Epoch 33/100
# 21s - loss: 7.9697e-04 - mean_squared_error: 7.9697e-04
# Epoch 34/100
# 20s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 35/100
# 21s - loss: 8.1910e-04 - mean_squared_error: 8.1910e-04
# Epoch 36/100
# 21s - loss: 8.6355e-04 - mean_squared_error: 8.6355e-04
# Epoch 37/100
# 21s - loss: 7.7715e-04 - mean_squared_error: 7.7715e-04
# Epoch 38/100
# 20s - loss: 9.8740e-04 - mean_squared_error: 9.8740e-04
# Epoch 39/100
# 20s - loss: 7.9617e-04 - mean_squared_error: 7.9617e-04
# Epoch 40/100
# 20s - loss: 7.3265e-04 - mean_squared_error: 7.3265e-04
# Epoch 41/100
# 21s - loss: 7.5807e-04 - mean_squared_error: 7.5807e-04
# Epoch 42/100
# 20s - loss: 7.4623e-04 - mean_squared_error: 7.4623e-04
# Epoch 43/100
# 20s - loss: 8.2589e-04 - mean_squared_error: 8.2589e-04
# Epoch 44/100
# 21s - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 45/100
# 20s - loss: 7.5879e-04 - mean_squared_error: 7.5879e-04
# Epoch 46/100
# 20s - loss: 7.0681e-04 - mean_squared_error: 7.0681e-04
# Epoch 47/100
# 20s - loss: 8.8140e-04 - mean_squared_error: 8.8140e-04
# Epoch 48/100
# 20s - loss: 6.6948e-04 - mean_squared_error: 6.6948e-04
# Epoch 49/100
# 21s - loss: 8.4374e-04 - mean_squared_error: 8.4374e-04
# Epoch 50/100
# 21s - loss: 7.4459e-04 - mean_squared_error: 7.4459e-04
# Epoch 51/100
# 20s - loss: 8.6130e-04 - mean_squared_error: 8.6130e-04
# Epoch 52/100
# 21s - loss: 6.3994e-04 - mean_squared_error: 6.3994e-04
# Epoch 53/100
# 20s - loss: 9.7696e-04 - mean_squared_error: 9.7696e-04
# Epoch 54/100
# 20s - loss: 9.3905e-04 - mean_squared_error: 9.3905e-04
# Epoch 55/100
# 21s - loss: 7.2435e-04 - mean_squared_error: 7.2435e-04
# Epoch 56/100
# 20s - loss: 6.8664e-04 - mean_squared_error: 6.8664e-04
# Epoch 57/100
# 20s - loss: 7.3766e-04 - mean_squared_error: 7.3766e-04
# Epoch 58/100
# 21s - loss: 8.4890e-04 - mean_squared_error: 8.4890e-04
# Epoch 59/100
# 20s - loss: 7.7231e-04 - mean_squared_error: 7.7231e-04
# Epoch 60/100
# 21s - loss: 6.9559e-04 - mean_squared_error: 6.9559e-04
# Epoch 61/100
# 20s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 62/100
# 20s - loss: 6.3551e-04 - mean_squared_error: 6.3551e-04
# Epoch 63/100
# 20s - loss: 6.9471e-04 - mean_squared_error: 6.9471e-04
# Epoch 64/100
# 20s - loss: 7.5035e-04 - mean_squared_error: 7.5035e-04
# Epoch 65/100
# 20s - loss: 7.4284e-04 - mean_squared_error: 7.4284e-04
# Epoch 66/100
# 20s - loss: 6.5604e-04 - mean_squared_error: 6.5604e-04
# Epoch 67/100
# 20s - loss: 7.3135e-04 - mean_squared_error: 7.3135e-04
# Epoch 68/100
# 20s - loss: 8.9665e-04 - mean_squared_error: 8.9665e-04
# Epoch 69/100
# 20s - loss: 6.7597e-04 - mean_squared_error: 6.7597e-04
# Epoch 70/100
# 21s - loss: 7.4913e-04 - mean_squared_error: 7.4913e-04
# Epoch 71/100
# 20s - loss: 7.8669e-04 - mean_squared_error: 7.8669e-04
# Epoch 72/100
# 20s - loss: 8.1581e-04 - mean_squared_error: 8.1581e-04
# Epoch 73/100
# 20s - loss: 7.1619e-04 - mean_squared_error: 7.1619e-04
# Epoch 74/100
# 20s - loss: 6.8987e-04 - mean_squared_error: 6.8987e-04
# Epoch 75/100
# 20s - loss: 7.9002e-04 - mean_squared_error: 7.9002e-04
# Epoch 76/100
# 20s - loss: 7.6129e-04 - mean_squared_error: 7.6129e-04
# Epoch 77/100
# 20s - loss: 6.9754e-04 - mean_squared_error: 6.9754e-04
# Epoch 78/100
# 20s - loss: 6.7989e-04 - mean_squared_error: 6.7989e-04
# Epoch 79/100
# 20s - loss: 8.3527e-04 - mean_squared_error: 8.3527e-04
# Epoch 80/100
# 20s - loss: 8.5420e-04 - mean_squared_error: 8.5420e-04
# Epoch 81/100
# 20s - loss: 6.5285e-04 - mean_squared_error: 6.5285e-04
# Epoch 82/100
# 20s - loss: 6.7457e-04 - mean_squared_error: 6.7457e-04
# Epoch 83/100
# 21s - loss: 8.7476e-04 - mean_squared_error: 8.7476e-04
# Epoch 84/100
# 21s - loss: 6.2744e-04 - mean_squared_error: 6.2744e-04
# Epoch 85/100
# 21s - loss: 7.0581e-04 - mean_squared_error: 7.0581e-04
# Epoch 86/100
# 21s - loss: 6.9864e-04 - mean_squared_error: 6.9864e-04
# Epoch 87/100
# 21s - loss: 8.9870e-04 - mean_squared_error: 8.9870e-04
# Epoch 88/100
# 20s - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 89/100
# 22s - loss: 6.9151e-04 - mean_squared_error: 6.9151e-04
# Epoch 90/100
# 21s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 91/100
# 21s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 92/100
# 21s - loss: 7.4559e-04 - mean_squared_error: 7.4559e-04
# Epoch 93/100
# 21s - loss: 7.0850e-04 - mean_squared_error: 7.0850e-04
# Epoch 94/100
# 21s - loss: 9.2234e-04 - mean_squared_error: 9.2234e-04
# Epoch 95/100
# 20s - loss: 7.1134e-04 - mean_squared_error: 7.1134e-04
# Epoch 96/100
# 20s - loss: 7.0046e-04 - mean_squared_error: 7.0046e-04
# Epoch 97/100
# 20s - loss: 6.7292e-04 - mean_squared_error: 6.7292e-04
# Epoch 98/100
# 20s - loss: 9.0176e-04 - mean_squared_error: 9.0176e-04
# Epoch 99/100
# 20s - loss: 6.2514e-04 - mean_squared_error: 6.2514e-04
# Epoch 100/100
# 20s - loss: 7.6321e-04 - mean_squared_error: 7.6321e-04

# %%
baseline, trainPredictPlot, testPredictPlot = visual_result(tweet_model, tweet_train_X, tweet_train_Y,\
                                                            tweet_test_X, tweet_test_Y, \
                                                            tweet_Y_base, data_info)

plt.plot(baseline)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Train Score: 0.92 RMSE
# Test Score: 2.04 RMSE

# %%
model.summary()
